# %% [markdown]
# # **Churn Prediction 'Die ZEIT' - Logistic Regression**
#
# #### **Pls install following packaged to your VE**
#
# **balancing:** <br/>
# conda install -c conda-forge imbalanced-learn <br/>
# **Xgboost classifierXgboost classifier:** <br/>
# conda install -c conda-forge xgboost <br/>
#
# ### **Used Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# Library for timing
from time import time

# Ignore warnings while plotting
import warnings
warnings.filterwarnings("ignore")

# Feature Engineering & Selection modules
from sklearn.preprocessing import MinMaxScaler, StandardScaler
#from mlxtend.feature_selection import SequentialFeatureSelector as SFS

# SUPERVISED LEARNING
# Libraries for classification issues
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# Libraries for classification and regression issues
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# Libraries for splitting data, hyperparameter tuning & Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline

# Librarie for data balancing
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# Libraries for model evaluation
from sklearn.metrics import classification_report, confusion_matrix, plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score           ############
from sklearn.metrics import roc_auc_score, roc_curve                                          ############
from sklearn.metrics import fbeta_score, make_scorer, mean_squared_error                      ############ ??? needed ???

# Display the whole content of the data frame
pd.set_option('display.max_columns', None)   # Displays all columns
pd.set_option('display.max_rows', None)      # Displays all rows

# Define decimal places shown in the notebook
pd.options.display.float_format = '{:,.2f}'.format

# Visualization
# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ### **Read Data**

# %%
df = pd.read_csv('/Users/chandrakanth/neuefischer/capstone-ZEIT-2020-ds/00_data/f_chtr_churn_traintable_nf.csv')

# %%
df.head(1)
# Out:
#    Unnamed: 0                        auftrag_new_id liefer_beginn_evt   kanal  \
# 0           0  6BE5B590-07EA-4543-B422-F7ABB2AF9464        2013-10-02  andere
#
#     objekt_name aboform_name zahlung_rhythmus_name  lesedauer  rechnungsmonat  \
# 0  ZEIT Digital     Probeabo              jährlich         68               0
#
#   zahlung_weg_name  studentenabo plz_1 plz_2 plz_3     ort  metropole  \
# 0       Bankeinzug             0     6    64   647  Erbach          0
#
#   land_iso_code  shop_kauf  unterbrechung anrede               titel  \
# 0            DE          4              0   Frau  akademischer Titel
#
#    avg_churn  email_am_kunden  zon_che_opt_in  zon_sit_opt_in  zon_zp_grey  \
# 0       0.13             1.00               0               0            0
#
#    zon_premium  zon_boa  zon_kommentar  zon_sonstige  zon_zp_red  zon_rawr  \
# 0            0        0              0             0           0         0
#
#    zon_community  zon_app_sonstige  zon_schach  zon_blog_kommentare  zon_quiz  \
# 0              0                 0           0                    0         0
#
#    cnt_abo  cnt_abo_diezeit  cnt_abo_diezeit_digital  cnt_abo_magazin  \
# 0        4                2                        0                2
#
#    cnt_umwandlungsstatus2_dkey abo_registrierung_min  nl_zeitbrief  \
# 0                            2   2005-01-27 07:53:59             2
#
#    nl_zeitshop  nl_zeitverlag_hamburg  nl_fdz_organisch  nl_blacklist_sum  \
# 0            2                      0                 0                 0
#
#    nl_bounced_sum  nl_aktivitaet nl_registrierung_min  nl_sperrliste_sum  \
# 0               1             14  2005-09-30 00:00:00                  0
#
#    nl_opt_in_sum  boa_reg  che_reg  sit_reg  sso_reg  received_anzahl_1w  \
# 0              0        0        0        0        1                   6
#
#    received_anzahl_1m  received_anzahl_3m  received_anzahl_6m  \
# 0                  14                  43                  80
#
#    opened_anzahl_1w  opened_anzahl_1m  opened_anzahl_3m  openedanzahl_6m  \
# 0                 4                15                38               74
#
#    clicked_anzahl_1w  clicked_anzahl_1m  clicked_anzahl_3m  clicked_anzahl_6m  \
# 0                  1                  2                  2                  2
#
#    unsubscribed_anzahl_1w  unsubscribed_anzahl_1m  unsubscribed_anzahl_3m  \
# 0                       0                       0                       0
#
#    unsubscribed_anzahl_6m  openrate_1w  clickrate_1w  openrate_1m  \
# 0                       0         0.67          0.25         1.07
#
#    clickrate_1m  openrate_3m  clickrate_3m  received_anzahl_bestandskunden_1w  \
# 0          0.13         0.88          0.05                                  0
#
#    received_anzahl_bestandskunden_1m  received_anzahl_bestandskunden_3m  \
# 0                                  0                                  0
#
#    received_anzahl_bestandskunden_6m  opened_anzahl_bestandskunden_1w  \
# 0                                  0                                0
#
#    opened_anzahl_bestandskunden_1m  opened_anzahl_bestandskunden_3m  \
# 0                                0                                0
#
#    openedanzahl_bestandskunden_6m  clicked_anzahl_bestandskunden_1w  \
# 0                               0                                 0
#
#    clicked_anzahl_bestandskunden_1m  clicked_anzahl_bestandskunden_3m  \
# 0                                 0                                 0
#
#    clicked_anzahl_bestandskunden_6m  unsubscribed_anzahl_bestandskunden_1w  \
# 0                                 0                                      0
#
#    unsubscribed_anzahl_bestandskunden_1m  \
# 0                                      0
#
#    unsubscribed_anzahl_bestandskunden_3m  \
# 0                                      0
#
#    unsubscribed_anzahl_bestandskunden_6m  openrate_bestandskunden_1w  \
# 0                                      0                        0.00
#
#    clickrate_bestandskunden_1w  openrate_bestandskunden_1m  \
# 0                         0.00                        0.00
#
#    clickrate_bestandskunden_1m  openrate_bestandskunden_3m  \
# 0                         0.00                        0.00
#
#    clickrate_bestandskunden_3m  received_anzahl_produktnews_1w  \
# 0                         0.00                               0
#
#    received_anzahl_produktnews_1m  received_anzahl_produktnews_3m  \
# 0                               0                               0
#
#    received_anzahl_produktnews_6m  opened_anzahl_produktnews_1w  \
# 0                               0                             0
#
#    opened_anzahl_produktnews_1m  opened_anzahl_produktnews_3m  \
# 0                             0                             0
#
#    openedanzahl_produktnews_6m  clicked_anzahl_produktnews_1w  \
# 0                            0                              0
#
#    clicked_anzahl_produktnews_1m  clicked_anzahl_produktnews_3m  \
# 0                              0                              0
#
#    clicked_anzahl_produktnews_6m  unsubscribed_anzahl_produktnews_1w  \
# 0                              0                                   0
#
#    unsubscribed_anzahl_produktnews_1m  unsubscribed_anzahl_produktnews_3m  \
# 0                                   0                                   0
#
#    unsubscribed_anzahl_produktnews_6m  openrate_produktnews_1w  \
# 0                                   0                     0.00
#
#    clickrate_produktnews_1w  openrate_produktnews_1m  \
# 0                      0.00                     0.00
#
#    clickrate_produktnews_1m  openrate_produktnews_3m  \
# 0                      0.00                     0.00
#
#    clickrate_produktnews_3m  received_anzahl_hamburg_1w  \
# 0                      0.00                           0
#
#    received_anzahl_hamburg_1m  received_anzahl_hamburg_3m  \
# 0                           0                           0
#
#    received_anzahl_hamburg_6m  opened_anzahl_hamburg_1w  \
# 0                           0                         0
#
#    opened_anzahl_hamburg_1m  opened_anzahl_hamburg_3m  \
# 0                         0                         0
#
#    openedanzahl_hamburg_6m  clicked_anzahl_hamburg_1w  \
# 0                        0                          0
#
#    clicked_anzahl_hamburg_1m  clicked_anzahl_hamburg_3m  \
# 0                          0                          0
#
#    clicked_anzahl_hamburg_6m  unsubscribed_anzahl_hamburg_1w  \
# 0                          0                               0
#
#    unsubscribed_anzahl_hamburg_1m  unsubscribed_anzahl_hamburg_3m  \
# 0                               0                               0
#
#    unsubscribed_anzahl_hamburg_6m  openrate_hamburg_1w  clickrate_hamburg_1w  \
# 0                               0                 0.00                  0.00
#
#    openrate_hamburg_1m  clickrate_hamburg_1m  openrate_hamburg_3m  \
# 0                 0.00                  0.00                 0.00
#
#    clickrate_hamburg_3m  received_anzahl_zeitbrief_1w  \
# 0                  0.00                             2
#
#    received_anzahl_zeitbrief_1m  received_anzahl_zeitbrief_3m  \
# 0                             5                            14
#
#    received_anzahl_zeitbrief_6m  opened_anzahl_zeitbrief_1w  \
# 0                            26                           1
#
#    opened_anzahl_zeitbrief_1m  opened_anzahl_zeitbrief_3m  \
# 0                           5                          13
#
#    openedanzahl_zeitbrief_6m  clicked_anzahl_zeitbrief_1w  \
# 0                         25                            0
#
#    clicked_anzahl_zeitbrief_1m  clicked_anzahl_zeitbrief_3m  \
# 0                            0                            0
#
#    clicked_anzahl_zeitbrief_6m  unsubscribed_anzahl_zeitbrief_1w  \
# 0                            0                                 0
#
#    unsubscribed_anzahl_zeitbrief_1m  unsubscribed_anzahl_zeitbrief_3m  \
# 0                                 0                                 0
#
#    unsubscribed_anzahl_zeitbrief_6m  openrate_zeitbrief_1w  \
# 0                                 0                   0.50
#
#    clickrate_zeitbrief_1w  openrate_zeitbrief_1m  clickrate_zeitbrief_1m  \
# 0                    0.00                   1.00                    0.00
#
#    openrate_zeitbrief_3m  clickrate_zeitbrief_3m  training_set  \
# 0                   0.93                    0.00             1
#
#   kuendigungs_eingangs_datum  churn               date_x
# 0                        NaN      0  2019-06-18 00:00:00

# %% [markdown]
# ### **Data insight**
# #### **Overview**

# %%
# Numeric and categorical features
shape_init_rows = df.shape[0]
shape_init_cols = df.shape[1]

print('The shape of the data set: {0} rows, {1} columns'.format(shape_init_rows, shape_init_cols))
print('   ')

cont_f = df.select_dtypes(include=['float64', 'int64'])
print('The number of numeric features: {0}'.format(len(cont_f.columns)))

cat_f = df.select_dtypes(include="object")
print('The number of objectlike features: {0}'.format(len(cat_f.columns)))
# Out:
# The shape of the data set: 209043 rows, 171 columns
#
# The number of numeric features: 153
# The number of objectlike features: 18

# %% [markdown]
# #### **Correlations**

# %%
# Visualize correlations with target variable
df.drop('churn', axis=1).corrwith(df.churn).sort_values().plot(kind='barh', color='b', figsize=(15, 50));
plt.title('Correlations of the features with the target variable (chrun)', fontsize=(18), fontweight='bold')
plt.ylabel('Features', fontsize=(15), fontweight='bold')
plt.xlabel('Correlation', fontsize=(15), fontweight='bold')
plt.xlim(-1, 1)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# ## **1 - Data Preprocessing for Modeling**
# ### **Drop Irrelevant Features**

# %%
df.drop(columns=['Unnamed: 0',
                 'auftrag_new_id',
                 'kuendigungs_eingangs_datum',
                 'avg_churn',
                 'training_set'], inplace=True)

# %% [markdown]
# ### **Drop Redundant Features**

# %%
df.drop(columns=['ort',
                 'plz_1',
                 'plz_2'], inplace=True)

# %% [markdown]
# ### **Dealing with Missing Values**

# %%
df.isna().sum().sort_values().tail()
# Out:
# opened_anzahl_3m       0
# openedanzahl_6m        0
# received_anzahl_1w     0
# date_x                 0
# email_am_kunden       12
# dtype: int64

# %%
df.dropna(subset=['email_am_kunden'], inplace=True)

# %%
# Numeric and categorical features
shape_a_nan_rows = df.shape[0]
shape_a_nan_cols = df.shape[1]


print('The shape of the data set (after dealing with missing values): {0} rows, {1} columns'.format(shape_a_nan_rows, shape_a_nan_cols))
print('   ')
print('By dropping the rows containing missing values, we removed {0} % of the rows \n(compared to the inital data set).'
      .format(round(((shape_init_rows-shape_a_nan_rows)/shape_init_rows)*100, ndigits=3)))
# Out:
# The shape of the data set (after dealing with missing values): 209031 rows, 163 columns
#
# By dropping the rows containing missing values, we removed 0.006 % of the rows
# (compared to the inital data set).

# %% [markdown]
# ### **Summary Preprocessing**

# %%
# Numeric and categorical features
print('The shape of the data set (after dropping columns and removing missing values): {0} rows, {1} columns'.format(df.shape[0], df.shape[1]))
print('   ')

cont_f = df.select_dtypes(include=['float64', 'int64'])
print('The number of numeric features (after dropping): {0}'.format(len(cont_f.columns)))

cat_f = df.select_dtypes(include="object")
print('The number of object features (after dropping): {0}'.format(len(cat_f.columns)))
# Out:
# The shape of the data set (after dropping columns and removing missing values): 209031 rows, 163 columns
#
# The number of numeric features (after dropping): 150
# The number of object features (after dropping): 13

# %% [markdown]
# ### **Dealing with DTypes and Dummies**

# %%
#df.info(verbose=1, null_counts=True)

# %% [markdown]
# #### **DType Conversions**

# %%
# Create list with categorical features and converting them -->> dtype = category
category_features = ['kanal',
                     'objekt_name',
                     'aboform_name',
                     'zahlung_rhythmus_name',
                     'zahlung_weg_name',
                     'land_iso_code',
                     'anrede',
                     'titel']

df[category_features] = df[category_features].astype('category')

# Removed temporarily: 'email_am_kunden'

# %%
# Convert columns with dates -->> dtype = datetime
df['liefer_beginn_evt'] = pd.to_datetime(df['liefer_beginn_evt'])
df['abo_registrierung_min'] = pd.to_datetime(df['abo_registrierung_min'])
df['nl_registrierung_min'] = pd.to_datetime(df['nl_registrierung_min'])
df['date_x'] = pd.to_datetime(df['date_x'])

# %%
# Creating new columns for datelike features (year & month)
df['liefer_beginn_evt_year'] = df['liefer_beginn_evt'].dt.strftime('%Y')
df['liefer_beginn_evt_month'] = df['liefer_beginn_evt'].dt.strftime('%m')

df['abo_registrierung_min_year'] = df['abo_registrierung_min'].dt.strftime('%Y')
df['abo_registrierung_min_month'] = df['abo_registrierung_min'].dt.strftime('%m')

df['nl_registrierung_min_year'] = df['nl_registrierung_min'].dt.strftime('%Y')
df['nl_registrierung_min_month'] = df['nl_registrierung_min'].dt.strftime('%m')

df['date_x_year'] = df['date_x'].dt.strftime('%Y')
df['date_x_month'] = df['date_x'].dt.strftime('%m')

# %%
# Dropping original datelike columns
df.drop(columns=['liefer_beginn_evt',
                 'abo_registrierung_min',
                 'nl_registrierung_min',
                 'date_x'], inplace=True)

# %%
# Replace values for foreign countrys ('xx') with '000' and convert dtype
df['plz_3'] = df['plz_3'].replace('xx', '000').astype('int')

# %% [markdown]
# #### **Dummy Creation**

# %%
# List with varibales to be converted into dummies
date_dum_features = ['liefer_beginn_evt_year',
                 'liefer_beginn_evt_month',
                 'abo_registrierung_min_year',
                 'abo_registrierung_min_month',
                 'nl_registrierung_min_year',
                 'nl_registrierung_min_month',
                 'date_x_year',
                 'date_x_month']

# %%
# Creating dummies
dummy_df1 = pd.get_dummies(df[category_features], drop_first=True)
dummy_df2 = pd.get_dummies(df[date_dum_features], drop_first=True)

# %%
# Columns containing initial information for dummy columns
df.drop(columns=category_features, inplace=True)
df.drop(columns=date_dum_features, inplace=True)

# %% [markdown]
# #### **Creat Clean df for Modeling (Concatinate Dummies to df)**

# %%
df_model = pd.concat([df, dummy_df1,dummy_df2], axis=1)

# %%
#df_model.info(verbose=1, null_counts=True)

# %% [markdown]
# ## **2 - Modeling**
# ### **Data Selection**
# + y = Target variable -->>. ```churn```
# + X = Predictors -->> ```remaining columns```

# %%
X = df_model.drop('churn',axis=1)
y = df_model['churn']

# %%
print('The target variable (y) has {0} rows.'.format(y.shape[0]))
print('   ')
print('The predictor variables (X) have {0} rows and {1} columns.'.format(X.shape[0], X.shape[1]))
# Out:
# The target variable (y) has 209031 rows.
#
# The predictor variables (X) have 209031 rows and 314 columns.

# %% [markdown]
# ### **Train-Test-Split**

# %%
# Splitting the data 
test_size = 0.3
RSEED = 42

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state = RSEED)

# %%
print('The test size is {} % of the preprocessed data set.'.format(test_size*100))
print('   ')
print('The train set has {0} rows.'.format(X_train.shape[0]))
print('   ')
print('The test set has {0} rows.'.format(X_test.shape[0]))
# Out:
# The test size is 30.0 % of the preprocessed data set.
#
# The train set has 146321 rows.
#
# The test set has 62710 rows.

# %% [markdown]
# ### **Function for: Predicting the Target Value ('churn') and Evaluation of the Model**

# %%
def run_models(models):
    '''
    Input:
        - models: List containing the model names initialized
    '''
    
    # Declare results as global variable
    global results
    # Dictionary for capturing the results
    results = {}

    # Looping trough the models
    for model in models:
        model_name = model.__class__.__name__
        results[model_name] = {}
        results[model_name] = \
        predict(X_train, X_test, y_train, y_test, model)
    
    #return results

# %%
# defining a function for prediction
def predict(X_train, X_test, y_train, y_test, model):
    '''
    Inputs:                              ########
       - X_train: Features training set  #####
       - y_train: Income training set    ####
       - X_test: Features testing set    ####
       - y_test: Income testing set      ####
       - model: The model algorithm to be trained and predicted on
    '''
    
    results = {}
    
    # Train the model by fitting the train data set (X_train y_train)     #################
    start = time() # Get start time
    model = model.fit(X_train ,y_train)
    end = time() # Get end time
      
    # Calculate the training time
    results['train_time'] = end - start
        
    # Get the predictions on the test set and training set,
    start = time() # Get start time
    predictions_test = model.predict(X_test)                              ########## Rename to y_pred_test
    predictions_train = model.predict(X_train)                            ########## Rename to y_pred_train
    #predictions_test_prob = model.predict_proba(X_test)
    #predictions_train_prob = model.predict_proba(X_train)
    end = time() # Get end time
    
    '''
    Evaluation through different parameters
    '''
    
    # Calculate the total prediction time
    results['pred_time'] = end - start
    
    # Compute accuracy on the train set
    results['acc_train'] = accuracy_score(y_train, predictions_train)
        
    # Compute accuracy on test set
    results['acc_test'] = accuracy_score(y_test, predictions_test)
    
    # Compute Precision_score on the train set
    results['Precision_train'] = precision_score(y_train, predictions_train)
    
    # Compute Precision_score on the test set
    results['Precision_test'] = precision_score(y_test, predictions_test)
    
    # Compute Recall_score on the train set
    results['Recall_train'] = recall_score(y_train, predictions_train)
    
    # Compute Recall_score on the test set
    results['Recall_test'] = recall_score(y_test, predictions_test)
    
    # Final results
    print('In the gym right now: {} '.format(model.__class__.__name__))               #############
    
    # Return the results
    return results

# %% [markdown]
# ### **Initialize the Models for Predictions**

# %%
# Initialize the models
model_NB = GaussianNB(var_smoothing=1e-09)

model_LG =  LogisticRegression()

model_KNN = KNeighborsClassifier(n_neighbors=5, metric='euclidean')

model_RF = RandomForestClassifier(n_estimators=500, min_samples_split = 2, 
                               max_leaf_nodes = 50, max_depth = 25, 
                               bootstrap = True, max_features = 'auto',   
                               n_jobs=-1, verbose = 1, random_state=RSEED)

model_XGB = XGBClassifier(n_estimators = 200, gamma = 100, 
                      learning_rate = 0.01, max_depth = 12, booster = 'gbtree',
                      scale_pos_weight = 1.5, objective='binary:logistic')

# %%
# List with models to be investigated
models = [model_NB, model_LG, model_KNN,model_RF,model_XGB] #, model_KNN, model_RF, model_XGB]

# Call the run_model function to run all models initialized and added to list
run_models(models)
# Out:
# In the gym right now: GaussianNB
# In the gym right now: LogisticRegression
# In the gym right now: KNeighborsClassifier
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   30.2s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=8)]: Done 500 out of 500 | elapsed:    1.2s finished
# In the gym right now: RandomForestClassifier
# In the gym right now: XGBClassifier

# %%
for result in results.items():
    print(result[1])#['train_time'])
# Out:
# {'train_time': 2.1320669651031494, 'pred_time': 2.2317941188812256, 'acc_train': 0.5157427846993938, 'acc_test': 0.5086589060755861, 'Precision_train': 0.3793236581067971, 'Precision_test': 0.37374618403837767, 'Recall_train': 0.8244292876046216, 'Recall_test': 0.8219171167533189}
# {'train_time': 8.495197296142578, 'pred_time': 0.38629984855651855, 'acc_train': 0.7025307372147539, 'acc_test': 0.7035879445064583, 'Precision_train': 0.6863711001642037, 'Precision_test': 0.6799058546631362, 'Recall_train': 0.11691804548486348, 'Recall_test': 0.11665236484781182}
# {'train_time': 10.171844005584717, 'pred_time': 260.16429805755615, 'acc_train': 0.8047717005761306, 'acc_test': 0.7079732100143518, 'Precision_train': 0.7430719539668322, 'Precision_test': 0.5488202320427584, 'Recall_train': 0.5890440432902295, 'Recall_test': 0.42501640502751}
# {'train_time': 30.806397914886475, 'pred_time': 2.3308351039886475, 'acc_train': 0.7211200032804587, 'acc_test': 0.7204911497368841, 'Precision_train': 0.7663191509345355, 'Precision_test': 0.752153744201458, 'Recall_train': 0.17554919637670247, 'Recall_test': 0.17187421129675431}
# {'train_time': 280.65680718421936, 'pred_time': 3.160593032836914, 'acc_train': 0.7409531099432071, 'acc_test': 0.7396587466113858, 'Precision_train': 0.6032021186950765, 'Precision_test': 0.5983851843487098, 'Recall_train': 0.5390623319061041, 'Recall_test': 0.5349553278481651}

# %%
def baseline_reporting ():

    # Displaying the results of predictions
    for result in results.items():
        # Header
        print ('Report on - {0}:\n'.format(i[0]))
        
        # Classification report
        print(classification_report(y_test, predictions_test))
        
        # Individual report
        print(pd.DataFrame.from_dict(result[1], orient='index').rename(columns={0:'uncleaned data'}))
        
        # Plot confusion matrix as heatmap
        #conf_mat = pd.crosstab(np.ravel(y_train), np.ravel(y_train_pred), colnames=["Predicted"], rownames=["Actual"])
        #sns.heatmap(conf_mat/np.sum(conf_mat), annot=True, cmap="Blues", fmt=".2%")
        #plt.show()
        #plt.close()
        
        print('\n========================================\n')

# %%
# converting the results into dataframe for plotting
results_df = pd.DataFrame(results).transpose()

# %%
results_df.head()
# Out:
#                         train_time  pred_time  acc_train  acc_test  \
# GaussianNB                    2.13       2.23       0.52      0.51
# LogisticRegression            8.50       0.39       0.70      0.70
# KNeighborsClassifier         10.17     260.16       0.80      0.71
# RandomForestClassifier       30.81       2.33       0.72      0.72
# XGBClassifier               280.66       3.16       0.74      0.74
#
#                         Precision_train  Precision_test  Recall_train  \
# GaussianNB                         0.38            0.37          0.82
# LogisticRegression                 0.69            0.68          0.12
# KNeighborsClassifier               0.74            0.55          0.59
# RandomForestClassifier             0.77            0.75          0.18
# XGBClassifier                      0.60            0.60          0.54
#
#                         Recall_test
# GaussianNB                     0.82
# LogisticRegression             0.12
# KNeighborsClassifier           0.43
# RandomForestClassifier         0.17
# XGBClassifier                  0.53

# %%
# making a new column with all model for easy plotting
models = ['GaussianNB', 'LogisticRegression', 'KNeighborsClassifier',
          'RandomForestClassifier', 'XGBClassifier'] 
# Using 'Address' as the column name 
# and equating it to the list 
results_df['Model'] = models

# %%
results_df.head()
results_df.to_csv("test")

# %%
# plotting the each results among all models  
for i in results_df.drop(["Model","train_time","pred_time"], axis=1).columns:
    ax = sns.barplot(x="Model", y=i, data=results_df)
    ax.set_xticklabels(ax.get_xticklabels(), ha="right", rotation=30);
    ax.set_title(f"{i} comparison - base models", fontsize=16);
    ax.set_xlabel(f"{i}", fontsize=16);
    ax.set_ylabel("metric score", fontsize=16);
    ax.set_ylim(0,1)
    plt.show()

# %%
# plotting the each results among all models  
for i in results_df.drop(["Model"], axis=1).columns:
    ax = sns.barplot(x="Model", y=i, data=results_df)
    ax.set_xticklabels(ax.get_xticklabels(), ha="right", rotation=30);
    ax.set_title(f"{i} comparison - base models", fontsize=16);
    ax.set_xlabel(f"{i}", fontsize=16);
    ax.set_ylabel("metric score", fontsize=16);
    ax.set_ylim(0,300)
    plt.show()
